# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\Admin\\Downloads\\Dataset\\iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
np.std(df)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# ...

# %%
df.drop(['species'], axis = 1, inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
np.std(df)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# sepal_length    0.825301
# sepal_width     0.432147
# petal_length    1.758529
# petal_width     0.760613
# dtype: float64

# %%
df = pd.read_csv('C:\\Users\\Admin\\Downloads\\Dataset\\titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dx=pd.DataFrame(df,columns=['Pclass', 'Age', 'Siblings/Spouses Aboard',
       'Parents/Children Aboard', 'Fare'])

# %%
dx
# Out:
#      Pclass   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0         3  22.0                      NaN                      NaN   7.2500
# 1         1  38.0                      NaN                      NaN  71.2833
# 2         3  26.0                      NaN                      NaN   7.9250
# 3         1  35.0                      NaN                      NaN  53.1000
# 4         3  35.0                      NaN                      NaN   8.0500
# ..      ...   ...                      ...                      ...      ...
# 886       2  27.0                      NaN                      NaN  13.0000
# 887       1  19.0                      NaN                      NaN  30.0000
# 888       3   NaN                      NaN                      NaN  23.4500
# 889       1  26.0                      NaN                      NaN  30.0000
# 890       3  32.0                      NaN                      NaN   7.7500
#
# [891 rows x 5 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dx.columns
# Out:
# Index(['Pclass', 'Age', 'Siblings/Spouses Aboard', 'Parents/Children Aboard',
#        'Fare'],
#       dtype='object')

# %%
dy=pd.DataFrame(df,columns=['Survived'])

# %%
dy
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(dx,dy,test_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(dx,dy,test_size=0.3)
#
# NameError: name 'train_test_split' is not defined

# %%
from sklearn import linear_model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(dx,dy,test_size=0.3)

# %%
x_train
# Out:
#      Pclass   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 430       1  28.0                      NaN                      NaN  26.5500
# 256       1   NaN                      NaN                      NaN  79.2000
# 293       3  24.0                      NaN                      NaN   8.8500
# 605       3  36.0                      NaN                      NaN  15.5500
# 645       1  48.0                      NaN                      NaN  76.7292
# ..      ...   ...                      ...                      ...      ...
# 50        3   7.0                      NaN                      NaN  39.6875
# 748       1  19.0                      NaN                      NaN  53.1000
# 28        3   NaN                      NaN                      NaN   7.8792
# 777       3   5.0                      NaN                      NaN  12.4750
# 190       2  32.0                      NaN                      NaN  13.0000
#
# [623 rows x 5 columns]

# %%
y_train
# Out:
#      Survived
# 430         1
# 256         1
# 293         0
# 605         0
# 645         1
# ..        ...
# 50          0
# 748         0
# 28          1
# 777         1
# 190         1
#
# [623 rows x 1 columns]

# %%
model=linear_model.LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 model.fit(x_train, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# ...

# %%
x_train.isnull().sum()
# Out:
# Pclass                       0
# Age                        125
# Siblings/Spouses Aboard    623
# Parents/Children Aboard    623
# Fare                         0
# dtype: int64

# %%
df['Age']=df['Age'].replace(to_replace=np.nan, value = 'unknown')

# %%
df['Siblings/Spouses Aboard']=df['Siblings/Spouses Aboard'].replace(to_replace=np.nan, value = 'unknown')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Siblings/Spouses Aboard'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ...

# %%
x_train.dtypes
# Out:
# Pclass                       int64
# Age                        float64
# Siblings/Spouses Aboard    float64
# Parents/Children Aboard    float64
# Fare                       float64
# dtype: object
